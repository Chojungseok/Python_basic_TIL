# %% [markdown]
# # Module
# - 같은 기능을 하는 코드끼리 나눠서 관리한다

# %%
# import {file_name}
import fact

# %%
print(fact)
# Out:
# <module 'fact' from '/Users/chojungseok/Desktop/DAMF2/python/fact.py'>

# %%
fact.factorial(5)
# Out:
# 120

# %%
fact.my_max(5,9)
# Out:
# 9

# %% [markdown]
# ### pypi
#
# - 파이썬 관련 패키지 사이트
# - 모듈들이 모여서 만들어진게 패키지

# %% [markdown]
# # Package
#
# ```
# myPackage/
#     __init__.py
#     math/
#         __init__.py
# ```
#
# - 패키지 안에 __init__.py파일이 존재해야 패키지로 인식

# %%
import myPackage

# %%
print(myPackage)
# Out:
# <module 'myPackage' from '/Users/chojungseok/Desktop/DAMF2/python/myPackage/__init__.py'>

# %%
from myPackage.math.formula import my_max

# %%
my_max(1,6)
# Out:
# 6

# %%
from myPackage.math import formula
formula.my_max(5,8)
# Out:
# 8

# %%
## *은 모든 항목을 다 가지고 온다
from myPackage.math.formula import * 

print(pi)
# Out:
# 3.14

# %%
formula = 1234
from myPackage.math import formula as f
print(formula)
print(f)
# Out:
# 1234
# <module 'myPackage.math.formula' from '/Users/chojungseok/Desktop/DAMF2/python/myPackage/math/formula.py'>

# %%
import myPackage.math
import myPackage.math.formula


myPackage.math.formula.my_max(2,3)
# Out:
# 3

# %% [markdown]
# ## 파이썬 내장 패키지

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
# .ceil()은 올림처리
math.ceil(math.e)
# Out:
# 3

# %%
## .floor은 내림
math.floor(math.e)
# Out:
# 2

# %%
## .sqrt 루트
math.sqrt(9)
# Out:
# 3.0

# %%
# 팩토리얼
math.factorial(10)
# Out:
# 3628800

# %%
from math import sqrt, factorial

# %%
sqrt(15)
# Out:
# 3.872983346207417

# %%
factorial(5)
# Out:
# 120

# %% [markdown]
# ### Random

# %%
import random

# %%
# 0~1 사이의 랜덤한 소수를 만들어냄
random.random()
# Out:
# 0.9806745885132978

# %%
# 지정한 범위의 자연수를 랜덤하게 뽑아준다
random.randint(1,10)
# Out:
# 3

# %%
## .seed(): ()안에 값을 지정해주면 값을 지정할 수 있음
random.seed(123)
random.random()
# Out:
# 0.052363598850944326

# %%
numbers = [1, 2, 3, 4, 5]

# %%
random.shuffle(numbers)
print(numbers)
# Out:
# [3, 5, 2, 4, 1]

# %%
# numbers 안에 있는 데이터에서 무작위로 1개를 뽑음(복원추출)
random.choice(numbers)
# Out:
# 3

# %%
# 비복원 추출
random.sample(numbers, 2)
# Out:
# [4, 2]

# %% [markdown]
# ## datetime

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 2, 18, 14, 52, 1, 21894)

# %%
datetime.today()
# Out:
# datetime.datetime(2025, 2, 18, 14, 52, 1, 26018)

# %%
datetime.utcnow()
# Out:
# /var/folders/fm/83s882x53rvddsxwgwzxcgdm0000gn/T/ipykernel_87115/3983769260.py:1: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   datetime.utcnow()
# datetime.datetime(2025, 2, 18, 5, 52, 1, 29727)

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2025, 2, 18, 14, 52, 1, 33584)

# %%
now.year
# Out:
# 2025

# %%
now.month
# Out:
# 2

# %%
now.day
# Out:
# 18

# %%
now.weekday()
# Out:
# 1

# %%
### 사람이 보기 좋은 방식
print(now)
# Out:
# 2025-02-18 14:52:01.033584

# %%
## 날짜의 포멧을 변경
now.strftime('%Y년 %m월 %d일')
# Out:
# '2025년 02월 18일'

# %%
x_mas = datetime(2025,12,25)
print(x_mas)
# Out:
# 2025-12-25 00:00:00

# %%
from datetime import timedelta

# %%
future = timedelta(days=-100)
print(x_mas + future)
# Out:
# 2025-09-16 00:00:00

# %%
x_mas - now
# Out:
# datetime.timedelta(days=309, seconds=32878, microseconds=966416)

# %% [markdown]
# ## 외부 라이브러리

# %% [markdown]
# ### Requests
# #### HTTP for Humans
#
# - 서버에다가 요청(request)을 보내면 응답(response)을 받는다

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
### .text를 통해서 request한 내용을 보여준다
print(r.text)
# Out:
# [{"id":"46719627421","type":"IssueCommentEvent","actor":{"id":224733,"login":"trasher","display_login":"trasher","gravatar_id":"","url":"https://api.github.com/users/trasher","avatar_url":"https://avatars.githubusercontent.com/u/224733?"},"repo":{"id":39182755,"name":"glpi-project/glpi","url":"https://api.github.com/repos/glpi-project/glpi"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/glpi-project/glpi/issues/16583","repository_url":"https://api.github.com/repos/glpi-project/glpi","labels_url":"https://api.github.com/repos/glpi-project/glpi/issues/16583/labels{/name}","comments_url":"https://api.github.com/repos/glpi-project/glpi/issues/16583/comments","events_url":"https://api.github.com/repos/glpi-project/glpi/issues/16583/events","html_url":"https://github.com/glpi-project/glpi/issues/16583","id":2142009204,"node_id":"I_kwDOAlXho85_rHd0","number":16583,"title":"Special character support","user":{"login":"jfael-isol","id":154451279,"node_id":"U_kgDOCTS9Tw","avatar_url":"https://avatars.githubusercontent.com/u/154451279?v=4","gravatar_id":"","url":"https://api.github.com/users/jfael-isol","html_url":"https://github.com/jfael-isol","followers_url":"https://api.github.com/users/jfael-isol/followers","following_url":"https://api.github.com/users/jfael-isol/following{/other_user}","gists_url":"https://api.github.com/users/jfael-isol/gists{/gist_id}","starred_url":"https://api.github.com/users/jfael-isol/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/jfael-isol/subscriptions","organizations_url":"https://api.github.com/users/jfael-isol/orgs","repos_url":"https://api.github.com/users/jfael-isol/repos","events_url":"https://api.github.com/users/jfael-isol/events{/privacy}","received_events_url":"https://api.github.com/users/jfael-isol/received_events","type":"User","user_view_type":"public","site_admin":false},"labels":[{"id":236900476,"node_id":"MDU6TGFiZWwyMzY5MDA0NzY=","url":"https://api.github.com/repos/glpi-project/glpi/labels/bug","name":"bug","color":"fc2929","default":true,"description":""}],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":{"url":"https://api.github.com/repos/glpi-project/glpi/milestones/49","html_url":"https://github.com/glpi-project/glpi/milestone/49","labels_url":"https://api.github.com/repos/glpi-project/glpi/milestones/49/labels","id":7725211,"node_id":"MI_kwDOAlXho84AdeCb","number":49,"title":"11.0.0","description":"","creator":{"login":"cedric-anne","id":33253653,"node_id":"MDQ6VXNlcjMzMjUzNjUz","avatar_url":"https://avatars.githubusercontent.com/u/33253653?v=4","gravatar_id":"","url":"https://api.github.com/users/cedric-anne","html_url":"https://github.com/cedric-anne","followers_url":"https://api.github.com/users/cedric-anne/followers","following_url":"https://api.github.com/users/cedric-anne/following{/other_user}","gists_url":"https://api.github.com/users/cedric-anne/gists{/gist_id}","starred_url":"https://api.github.com/users/cedric-anne/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/cedric-anne/subscriptions","organizations_url":"https://api.github.com/users/cedric-anne/orgs","repos_url":"https://api.github.com/users/cedric-anne/repos","events_url":"https://api.github.com/users/cedric-anne/events{/privacy}","received_events_url":"https://api.github.com/users/cedric-anne/received_events","type":"User","user_view_type":"public","site_admin":false},"open_issues":53,"closed_issues":713,"state":"open","created_at":"2022-03-01T14:59:31Z","updated_at":"2025-02-18T14:34:00Z","due_on":null,"closed_at":null},"comments":3,"created_at":"2024-02-19T10:15:07Z","updated_at":"2025-02-19T07:25:16Z","closed_at":null,"author_association":"NONE","sub_issues_summary":{"total":0,"completed":0,"percent_completed":0},"active_lock_reason":null,"body":"### Code of Conduct\n\n- [X] I agree to follow this project's Code of Conduct\n\n### Is there an existing issue for this?\n\n- [X] I have searched the existing issu ...

# %%
r = requests.get('https://naver.com')

print(r.text)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="google-site-verification" content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_241121.css"> <link rel="canonical" href="https://www.naver.com/"> <link rel="alternate" media="only screen and (max-width: 767px)" href="https://m.naver.com/"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED-EDIT","title":"탕후루","url":"https://blog.naver.com/rubyzio/223758823382","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20250218_1095/upload_1739858471837Zk8uN.jpg"},"highlight":"레시피 집중탐구","desc":"팡팡 터지는 달콤한 과즙","desc2":"한 입에 쏙쏙 먹을 수 있는 간식","_id":"654ad80598c6dbca70ba6ce7"},{"@type":"MATERIAL-PC-FEED-EDIT","title":"도심 속에서 맛볼 수 있는 겨울 제철 생선 맛집","url":"https://blog.naver.com/eyesmag2013/223755616216","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20250214_1095/upload_1739518768435FcXAd.jpg"},"highlight":"푸드스토리","desc":"제철 과메기와 코다리부터","desc2":"지금만 먹을 수 있는 이색 요리까지","_id":"654ad80598c6dbca70ba6ce8"},{"@type":"MATERIAL-PC-FEED-EDIT","title":"구운 김의 향과 맛 가득한 소금빵 만드는 방법","url":"https://tv.naver.com/v/69173070","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20250214_1095/upload_17395187746640UZZE.jpg"},"highlight":"오늘의 푸드TV","desc":"먹어도 먹어도 질리지 않아!","desc2":"김 좋아하면 꼭 한 번 해보세요","video":{"playTime":"07:06"},"_id":"654ad80598c6dbca70ba6ce9"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"layout":"BIG-IMAGE-3","orderRandom":false,"_id":null,"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":"PC-FEED-RECIPE-CAS-EDIT","@template":"PC-FEED-CAS-EDIT","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"꼬마김밥 만들기 재료 스팸김밥 간단한 꼬마김밥 레시피","url":"https://in.naver.com/firehouse79/contents/internal/773779751531328","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNDEyMjZfODcg%2FMDAxNzM1MTk1ODEyMDYw.4fbPSr_8U9QFFHxaR5wZSnSZOAVReqU1hnBzcj5FggAg.caXVRV8_BfxNPcragxs4x-KfqSxcQyalEF36hnIvYJ4g.JPEG%2FDSC00217.jpg%22&type=nf308_200&service=navermain"},"source":{"url":"https://blog.naver.com/firehouse79","name":"반이짝이","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyMTAzMTFfMjk3%2FMDAxNjE1NDQzMzYyMzk1.a9CHCEcjSxBY_NDq6Yq8PQ2Tenovb0WL0dFZF48Qwz0g.hSNxcky9oxjjqmhqtRQX4NpG7VjOjSj1F05EmpqYjREg.JPEG.firehouse79%2FprofileImage.jpg%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"6441ca92c499cc07f334c56a"},{"@type":"MATERIAL-PC-FEED","title":"당근라페 만들기 당근 라페 샐러드 레시피 간단 당근요리","url":"https://in.naver.com/wookyungmom/contents/internal/787729659851904","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTAyMDJfNzAg%2FMDAxNzM4NDg3ODIyNjA2.xN4vVM0IrM1Nqf3QiAn0pjKtpi_DCzcvdpKp8gPqepcg.bX71G8PKWYgDSWy3P4u-jG0A4kHaO82bxVXw0zUh2y8g.JPEG%2FIMG_4302.JPG%22&type=nf308_200&service=navermain"},"source":{"url":"https://blog.naver.com/wookyungmom","name":"투우맘","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyNTAyMDhfMTE0%2FMDAxNzM5MDIxNTU3MDM1.SN-m0lOkOwcQy0nr5m8LPqP4UJhKtUrWmGBtDTNfFnsg.cuSpZB9wyCa6wOzyU5eYagIIfgdWXD4uhjia2hHEEyUg.JPEG%2FprofileImage.jpg%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"6441ca92c499cc07f334c56b"},{"@type":"MATERIAL-PC-FEED","title":"집밥 다이어트식단 지난주 챙겨먹은 혼밥 다이어트메뉴","url":"https://in.naver.com/mykim0403/contents/internal/792799888480192","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTAyMTdfMTIy%2FMDAxNzM5NzY0MzExMTA1.ladtu56XSIM38hScWBQ6NLgXr0-LEKk17jSfeUVyesUg.PN9RgeBmtmeT9w2fRXpa9EKOu1uSGndv1tkupfOdrQAg.JPEG%2F900%EF%BC%BF20250217%EF%BC%BF090254.jpg%22&type=nf308_200&service=navermain"},"source":{"url":"https://blog.naver.com/mykim0403","name":"은효맘미미","image":{"url":"https://s.pstatic.n ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"233dca99-ee93-11ef-9365-81518209a8da","@provider":"lambda","@lastModifiedAt":[2025,2,19,7,28,39,92000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250219 16:11:00","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250218 17:34:00","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250219 16:13:54","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/353.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/353.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250219 09:55:50","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250219 16:15:19","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250219 09:19:04","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250219 15:10:46","_id":null,"@type":"PC-NEWS ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"한덕수 \"尹 다른 선택 설득 못해…계엄은 무관\"…탄핵기각 요청","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015222639","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[속보] 정부 \"北포로 요청시 전원수용이 원칙…우크라에도 입장 전달\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015222741","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec43489"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"윤 대통령, 내일 중앙지법 첫 형사재판·구속취소 심문 참석","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015222482","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348a"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"尹측 \"대통령, 헌재 결과 당연히 승복…공정한 결정 촉구\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015222735","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"이재명 선거법 2심 공소장 변경…\"허위발언 특정\"vs\"논리 비약\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015222434","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348c"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[2보] '北어민 강제북송' 정의용·서훈·노영민 징역형 선고유예","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015222537","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348d"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"고법, '10·26 사건' 김재규 재심 결정…\"수사 때 가혹행위\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015222609","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348e"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"선거법 위반 혐의 이상식 의원 1심 벌금 300만원…당선무효형","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015222602","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348f"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"지방 미분양 3천가구 LH가 매입…부산·대전·안산 철도 지하화","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015222031","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"67a2ee96c028eff225115470"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"초등생 살해 교사 ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"45dc677d-ee93-11ef-9365-25eaba7e5edc","@provider":"lambda","@lastModifiedAt":[2025,2,19,7,29,37,171000000]}
# window["EAGER-DATA"]["PC-HEADLINE-AD"] = {"@type":"PC-HEADLINE-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N401","adlineId":"2988476","vimp100p0s":"https://siape.veta.naver.com/fxview?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FGe2N8IvCCfRlc3992%2FDfOZNArUtQZ%2B2ZiGNcbrnFmKn&ac=9084811&src=7476839&evtcd=V900&x_ti=1585&tb=&oid=&sid1=&sid2=&rk=ZRhz3xm6lSj5HJ5y0rlhxg&eltts=z8STi8qe5HZ%2F%2BncyXok1yw%3D%3D&brs=Y&&eid=V900","assets":{"hl_web_img":{"url":"https://ssl.pstatic.net/melona/libs/1524/1524588/25456305626c24b9c24a_20250217115128240.png","alt":"[광고]초록우산 국내아동 돕기 켈로그 키트 전원증정","w":488,"h":216},"hl_web_img_dark":{"url":"https://ssl.pstatic.net/melona/libs/1524/1524588/a634031baf8ca26b9914_20250217115130765.png","alt":"[광고]초록우산 국내아동 돕기 켈로그 키트 전원증정","w":488,"h":216},"hl_link":{"url":"https://siape.veta.naver.com/fxclick?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FGe2N8IvCCfRlc3992%2FDfOZNArUtQZ%2B2ZiGNcbrnFmKn&ac=9084811&src=7476839&br=4684859&evtcd=P901&x_ti=1585&tb=&oid=&sid1=&sid2=&rk=ZRhz3xm6lSj5HJ5y0rlhxg&eltts=z8STi8qe5HZ%2F%2BncyXok1yw%3D%3D&brs=Y&&a=","clicktracking":"https://ssl.pstatic.net/tveta/libs/1by1.gif"},"bb_web_img":{"url":"https://ssl.pstatic.net/melona/libs/1524/1524588/d78f88a5d8955d01515f_20250217115133210.png","alt":"초록우산","w":80,"h":80},"bb_web_img_dark":{"url":"https://ssl.pstatic.net/melona/libs/1524/1524588/d78f88a5d8955d01515f_20250217115133210.png","alt":"초록우산","w":80,"h":80},"bb_link":{"url":"https://siape.veta.naver.com/fxclick?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FGe2N8IvCCfRlc3992%2FDfOZNArUtQZ%2B2ZiGNcbrnFmKn&ac=9084811&src=7476841&br=4684860&evtcd=BUBBLE_CLK_1&x_ti=1585&tb=&oid=&sid1=&sid2=&rk=ZRhz3xm6lSj5HJ5y0rlhxg&eltts=z8STi8qe5HZ%2F%2BncyXok1yw%3D%3D&brs=Y&&a=...","clicktracking":"https://ssl.pstatic.net/tveta/libs/1by1.gif"},"bb_web_text":"초록우산"}},"_id":null,"@type":null,"@code":"PC-HEADLINE-AD","@template":"PC-HEADLINE-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"29402f8d-ee93-11ef-8f69-fd0cb9ba2b28","@provider":"lambda","@lastModifiedAt":[2025,2,19,7,28,49,167000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"426ae6f7-ee93-11ef-8f69-b53daa9dd58d","@provider":"lambda","@lastModifiedAt":[2025,2,19,7,29,31,391000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.shpt","name":"쇼핑투데이","id":"PC-MEDIA-SHOPPING-TODAY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2024-04-18T16:13:27.109"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"2ba6cea9-ee93-11ef-9365-c151159b1a91","@provider":"lambda","@lastModifiedAt":[2025,2,19,7,28,53,226000000]}
# </script> <script defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.a163af38.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/preload.33507660.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/search.b23b1e46.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/main.73f9d433.js?o=www" crossorigin="anonymous"></script><link href="https://pm.pstatic.net/resources/css/main.e72d33f5.css" rel="stylesheet"></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div>   <script type="text/plain" id="ad-timeboard-response" data-gfp-banner-size="1444x150" data-gfp-banner-type="full">{"payload":{"requestId":"74600e5b22d8412c92f2ae53828e006b","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"lazyRenderMediaFailed":[{"url":"https://tivan.naver.com/sc2/93/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":73,"adDivId":"ad_timeboard","ads":[{"encrypted":"EffwidO-GY7QFrBtswTolE1d1Mi8WabsF-IR1IYZpuvbpD3Kws-gf-PC0cz6K1R8jDlE9pgbd8ZQzz6PnUBktVr1W3QKYDAvFMWfHRHQZavkqyPqlPgoo98fdiBu0kZOAYjzaMcDSBXl6Z90PH8ziByOgzIAtkM5V9OVWClBX6DYZ9HzTFdBHLIHWzjG79TrKTdKkOTOURo9Ty7I3-6f6iNt8FuL4RXp83taY-uOZa8is6Y2B8QM7_nPz3xT874HomvK9I83EVlPrhliBrkcR2CrcOMePSDeaapcCrnTGGBhlhQLaXBwMM15dnf71_txlvHEI2E3PeAzZ7LsT3KowCo5jdLrT4i-aggmU7mBO6uNCrcMkAz1BLVeC9I7rFEfsxQb3EGwhbpBqZIKQT9i_b5ixb-zwpQIw57QjQAbtmGiC3r4ymRRoo1rdX0ZvsnxY6-Fv1Y9Fb5W-_jM7i_N-k44NXZDstOwSAk_xABwkz8qSRGlCWTVLaLkUVkInXaAZ57D0tgRk8Ubk_ON9DwkPa0FmnK3F4i2EV--m6cXPsDomVCsOBbILnmnE9Vxj3DhpHRgEb1PVcq1pwX1_eAh8qVr5lSvObXHrg9PVV3_AeVC8W8mQnjGhji29CDEJAccA04r1XpZxR0GuFd_FL5mrNAViop-1f96Ugi4tVnV5MwmsjWrNYd44zsDPfOMwH78sUAmLdCcpeBfIAgDFbmvNpHKnstd15-Cdldi4IiBX1m3ttZCm8BgzhF7GeJ7bbnh","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5M7nINmZOAsAZuSyPbCZ38r%2BJKr3MzmBph2lv1OEu0ocZ7H0Lo3JMSSJL1qM2Pf%2FalntjfCLwgn0ZXN%2Ffdvw3zmTQK1LUGftmbIBWexIpibH0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvbdMAtSn%2B9Id4vH4MuGzFJiErLLp1Ox71Vg1K%2FFXnNMQA\u0026ac=9084240\u0026src=7476837\u0026evtcd=BID_WIN\u0026x_ti=1500\u0026rk=fmdv81Xb6TwKG9pwlTCIhQ\u0026eltts=z8STi8qe5HZ%2F%2BncyXok1yw%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","cid":"1524856","crid":"2718784","exp":1781,"adm":"%3Cscript%20type%3D%22text%2Fjavascript%22%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fassets%2Fjs%2Fpc%2Fmain%2Fmin%2Fpc.veta.core.min.js%3F2 ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div id="topSearchWrap" class="header_inner"> <div id="special-logo" class="search_special_bg"></div> <div id="timeboard-ex" class="ad_area" style="min-width:1340px"> </div> <div id="search_area" class="search_area" style="border-color:#fff"> <div class="search_group"> <div id="search" class="search_group_inner"> <h1 id="special-input-logo" class="search_logo"></h1> <form id="sform" name="search" role="search" action="https://search.naver.com/search.naver" method="get"> <fieldset> <legend class="blind">검색</legend> <input type="hidden" name="where" value="nexearch"/> <input type="hidden" id="sm" name="sm" value="top_hty"/> <input type="hidden" id="fbm" name="fbm" value="0"/> <input type="hidden" id="acr" name="acr" value="" disabled="disabled"/> <input type="hidden" id="acq" name="acq" value="" disabled="disabled"/> <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled"/> <input type="hidden" id="ie" name="ie" value="utf8"/> <input type="hidden" id="acir" name="acir" value="" disabled="disabled"/> <input type="hidden" id="os" name="os" value="" disabled="disabled"/> <input type="hidden" id="bid" name="bid" value="" disabled="disabled"/> <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled"/> <input type="hidden" id="eid" name="eid" value="" disabled="disabled"/> <input type="hidden" id="mra" name="mra" value="" disabled="disabled"/> <div class="search_input_box"> <input id="query" name="query" type="search" title="검색어를 입력해 주세요." placeholder="검색어를 입력해 주세요." maxlength="255" autocomplete="off" class="search_input" data-atcmp-element/> </div> <button type="submit" class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})'> <span class="ico_btn_search_svg"> <svg id="search-btn" viewBox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"/> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button id="ke_kbd_btn" type="button" class="btn_keyboard" aria-pressed="false"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button id="nautocomplete" type="button" class="btn_arrow" data-atcmp-element> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right-first"></div> <div id="search-right-second"></div> <div id="shortcutArea" class="shortcut_area" role="navigation" aria-label="주요 서비스"></div> <div id="topAsideArea" class="menu_area"></div> <div id="topPayArea" class="pay_area"></div> <div id="topTalkArea" class="talk_area"></div> <div id="topNotiArea" class="notify_area"></div> <div id="topShoppingArea" class="shopping_area"></div> </div> </div> <div id="container" role="main"> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div>      <script> window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20250219163017',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var o=i&&i.content&&i.content.input&&i.content.input.placeholder;if(o){var s=document.getElementById("query");s&&o&&s.setAttribute("title",o),s&&o&&s.setAttribute("placeholder",o)}}()</script> </body> </html>

# %%
payload = {'key1':'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params= payload)

# %%
print(r.url)
print(r.text)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2
# {
#   "args": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-67b58890-33980c7018697b5c75c9dccf"
#   },
#   "origin": "183.96.187.252",
#   "url": "https://httpbin.org/get?key1=value1&key2=value2"
# }

# %% [markdown]
# https://httpbin.org/get : 기본적인 주소
# ? : 분기점
# key1=value1&key2=value2 : 추가적인 parameter, &를 기준으로 나눠진다

# %%
payload = {'query':'파이썬'}
r = requests.get('https://search.naver.com/search.naver', params= payload)

print(r.url)
# Out:
# https://search.naver.com/search.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC

# %%
r = requests.get('https://api.github.com/events')
print(type(r.json))
r.json()[0]
# Out:
# <class 'method'>
# {'id': '46719750351',
#  'type': 'PullRequestEvent',
#  'actor': {'id': 39814207,
#   'login': 'pull[bot]',
#   'display_login': 'pull',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/pull[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#  'repo': {'id': 555321393,
#   'name': 'GreatDick/AdguardFilters',
#   'url': 'https://api.github.com/repos/GreatDick/AdguardFilters'},
#  'payload': {'action': 'opened',
#   'number': 450,
#   'pull_request': {'url': 'https://api.github.com/repos/GreatDick/AdguardFilters/pulls/450',
#    'id': 2343847554,
#    'node_id': 'PR_kwDOIRmIMc6LtEaC',
#    'html_url': 'https://github.com/GreatDick/AdguardFilters/pull/450',
#    'diff_url': 'https://github.com/GreatDick/AdguardFilters/pull/450.diff',
#    'patch_url': 'https://github.com/GreatDick/AdguardFilters/pull/450.patch',
#    'issue_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/issues/450',
#    'number': 450,
#    'state': 'open',
#    'locked': False,
#    'title': '[pull] master from AdguardTeam:master',
#    'user': {'login': 'pull[bot]',
#     'id': 39814207,
#     'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#     'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/pull%5Bbot%5D',
#     'html_url': 'https://github.com/apps/pull',
#     'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#     'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#     'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#     'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#     'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#     'type': 'Bot',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'body': 'See [Commits](/GreatDick/AdguardFilters/pull/450/commits) and [Changes](/GreatDick/AdguardFilters/pull/450/files) for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull) (v2.0.0-alpha.1)\n\n_Can you help keep this open source service alive? **[💖 Please sponsor : )](https://prod.download/pull-pr-sponsor)**_',
#    'created_at': '2025-02-19T07:29:19Z',
#    'updated_at': '2025-02-19T07:29:20Z',
#    'closed_at': None,
#    'merged_at': None,
#    'merge_commit_sha': '7d3706a7515f6a8f037695cd339ed3212714c9f4',
#    'assignee': None,
#    'assignees': [],
#    'requested_reviewers': [],
#    'requested_teams': [],
#    'labels': [{'id': 4704583052,
#      'node_id': 'LA_kwDOIRmIMc8AAAABGGo9jA',
#      'url': 'https://api.github.com/repos/GreatDick/AdguardFilters/labels/:arrow_heading_down:%20pull',
#      'name': ':arrow_heading_down: pull',
#      'color': 'ededed',
#      'default': False,
#      'description': None}],
#    'milestone': None,
#    'draft': False,
#    'commits_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/pulls/450/commits',
#    'review_comments_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/pulls/450/comments',
#    'review_comment_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/pulls/comments{/number}',
#    'comments_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/issues/450/comments',
#    'statuses_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/statuses/2e6ac2ac9f580a2184fa8ec506c40fd7b9bc45b0',
#    'head': {'label': 'AdguardTeam:master',
#     'ref': 'master',
#     'sha': '2e6ac2ac9f580a2184fa8ec506c40fd7b9bc45b0',
#     'user': {'login': 'AdguardTeam',
#      'id': 8361145,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgzNjExNDU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/8361145?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/AdguardTeam',
#      'html_url': 'https://github.com/AdguardTeam',
#      'followers_url': 'https://api.github.com/users/AdguardTeam/followers',
#      'following_url': 'https://api.github.com/users/AdguardTeam/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/AdguardTeam/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/AdguardTeam/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/AdguardTeam/subscriptions',
#      'organizations_url': 'https://api.github.com/users/AdguardTeam/orgs',
#      'repos_url': 'https://api.github.com/users/AdguardTeam/repos',
#      'events_url': 'https://api.github.com/users/AdguardTeam/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/AdguardTeam/received_events',
#      'type': 'Organization',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'repo': {'id': 22637619,
#      'node_id': 'MDEwOlJlcG9zaXRvcnkyMjYzNzYxOQ==',
#      'name': 'AdguardFilters',
#      'full_name': 'AdguardTeam/AdguardFilters',
#      'private': False,
#      'owner': {'login': 'AdguardTeam',
#       'id': 8361145,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgzNjExNDU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8361145?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AdguardTeam',
#       'html_url': 'https://github.com/AdguardTeam',
#       'followers_url': 'https://api.github.com/users/AdguardTeam/followers',
#       'following_url': 'https://api.github.com/users/AdguardTeam/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AdguardTeam/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AdguardTeam/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AdguardTeam/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AdguardTeam/orgs',
#       'repos_url': 'https://api.github.com/users/AdguardTeam/repos',
#       'events_url': 'https://api.github.com/users/AdguardTeam/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AdguardTeam/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'html_url': 'https://github.com/AdguardTeam/AdguardFilters',
#      'description': 'AdGuard Content Blocking Filters',
#      'fork': False,
#      'url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters',
#      'forks_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/forks',
#      'keys_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/teams',
#      'hooks_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/hooks',
#      'issue_events_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/events',
#      'assignees_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/tags',
#      'blobs_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/languages',
#      'stargazers_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/stargazers',
#      'contributors_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/contributors',
#      'subscribers_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/subscribers',
#      'subscription_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/subscription',
#      'commits_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/merges',
#      'archive_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/downloads',
#      'issues_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/AdguardTeam/AdguardFilters/deployments',
#      'created_at': '2014-08-05T09:12:41Z',
#      'updated_at': '2025-02-19T07:27:52Z',
#      'pushed_at': '2025-02-19T07:27:48Z',
#      'git_url': 'git://github.com/AdguardTeam/AdguardFilters.git',
#      'ssh_url': 'git@github.com:AdguardTeam/AdguardFilters.git',
#      'clone_url': 'https://github.com/AdguardTeam/AdguardFilters.git',
#      'svn_url': 'https://github.com/AdguardTeam/AdguardFilters',
#      'homepage': 'https://adguard.com/',
#      'size': 755030,
#      'stargazers_count': 3395,
#      'watchers_count': 3395,
#      'language': 'Adblock Filter List',
#      'has_issues': True,
#      'has_projects': True,
#      'has_downloads': True,
#      'has_wiki': False,
#      'has_pages': False,
#      'has_discussions': False,
#      'forks_count': 663,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 366,
#      'license': {'key': 'gpl-3.0',
#       'name': 'GNU General Public License v3.0',
#       'spdx_id': 'GPL-3.0',
#       'url': 'https://api.github.com/licenses/gpl-3.0',
#       'node_id': 'MDc6TGljZW5zZTk='},
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': ['adblock', 'adguard', 'filter-list', 'open-source', 'ublock'],
#      'visibility': 'public',
#      'forks': 663,
#      'open_issues': 366,
#      'watchers': 3395,
#      'default_branch': 'master'}},
#    'base': {'label': 'GreatDick:master',
#     'ref': 'master',
#     'sha': '6db81059de1b9906991756f74893a29252a593fb',
#     'user': {'login': 'GreatDick',
#      'id': 10369047,
#      'node_id': 'MDQ6VXNlcjEwMzY5MDQ3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/10369047?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/GreatDick',
#      'html_url': 'https://github.com/GreatDick',
#      'followers_url': 'https://api.github.com/users/GreatDick/followers',
#      'following_url': 'https://api.github.com/users/GreatDick/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/GreatDick/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/GreatDick/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/GreatDick/subscriptions',
#      'organizations_url': 'https://api.github.com/users/GreatDick/orgs',
#      'repos_url': 'https://api.github.com/users/GreatDick/repos',
#      'events_url': 'https://api.github.com/users/GreatDick/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/GreatDick/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'repo': {'id': 555321393,
#      'node_id': 'R_kgDOIRmIMQ',
#      'name': 'AdguardFilters',
#      'full_name': 'GreatDick/AdguardFilters',
#      'private': False,
#      'owner': {'login': 'GreatDick',
#       'id': 10369047,
#       'node_id': 'MDQ6VXNlcjEwMzY5MDQ3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/10369047?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GreatDick',
#       'html_url': 'https://github.com/GreatDick',
#       'followers_url': 'https://api.github.com/users/GreatDick/followers',
#       'following_url': 'https://api.github.com/users/GreatDick/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GreatDick/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GreatDick/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GreatDick/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GreatDick/orgs',
#       'repos_url': 'https://api.github.com/users/GreatDick/repos',
#       'events_url': 'https://api.github.com/users/GreatDick/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GreatDick/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'html_url': 'https://github.com/GreatDick/AdguardFilters',
#      'description': 'AdGuard Content Blocking Filters',
#      'fork': True,
#      'url': 'https://api.github.com/repos/GreatDick/AdguardFilters',
#      'forks_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/forks',
#      'keys_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/teams',
#      'hooks_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/hooks',
#      'issue_events_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/events',
#      'assignees_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/tags',
#      'blobs_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/languages',
#      'stargazers_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/stargazers',
#      'contributors_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/contributors',
#      'subscribers_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/subscribers',
#      'subscription_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/subscription',
#      'commits_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/merges',
#      'archive_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/downloads',
#      'issues_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/GreatDick/AdguardFilters/deployments',
#      'created_at': '2022-10-21T10:56:52Z',
#      'updated_at': '2025-02-19T01:29:23Z',
#      'pushed_at': '2025-02-19T01:29:19Z',
#      'git_url': 'git://github.com/GreatDick/AdguardFilters.git',
#      'ssh_url': 'git@github.com:GreatDick/AdguardFilters.git',
#      'clone_url': 'https://github.com/GreatDick/AdguardFilters.git',
#      'svn_url': 'https://github.com/GreatDick/AdguardFilters',
#      'homepage': 'https://adguard.com/',
#      'size': 742443,
#      'stargazers_count': 0,
#      'watchers_count': 0,
#      'language': 'Adblock Filter List',
#      'has_issues': False,
#      'has_projects': True,
#      'has_downloads': True,
#      'has_wiki': False,
#      'has_pages': False,
#      'has_discussions': False,
#      'forks_count': 0,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 1,
#      'license': {'key': 'gpl-3.0',
#       'name': 'GNU General Public License v3.0',
#       'spdx_id': 'GPL-3.0',
#       'url': 'https://api.github.com/licenses/gpl-3.0',
#       'node_id': 'MDc6TGljZW5zZTk='},
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': [],
#      'visibility': 'public',
#      'forks': 0,
#      'open_issues': 1,
#      'watchers': 0,
#      'default_branch': 'master'}},
#    '_links': {'self': {'href': 'https://api.github.com/repos/GreatDick/AdguardFilters/pulls/450'},
#     'html': {'href': 'https://github.com/GreatDick/AdguardFilters/pull/450'},
#     'issue': {'href': 'https://api.github.com/repos/GreatDick/AdguardFilters/issues/450'},
#     'comments': {'href': 'https://api.github.com/repos/GreatDick/AdguardFilters/issues/450/comments'},
#     'review_comments': {'href': 'https://api.github.com/repos/GreatDick/AdguardFilters/pulls/450/comments'},
#     'review_comment': {'href': 'https://api.github.com/repos/GreatDick/AdguardFilters/pulls/comments{/number}'},
#     'commits': {'href': 'https://api.github.com/repos/GreatDick/AdguardFilters/pulls/450/commits'},
#     'statuses': {'href': 'https://api.github.com/repos/GreatDick/AdguardFilters/statuses/2e6ac2ac9f580a2184fa8ec506c40fd7b9bc45b0'}},
#    'author_association': 'NONE',
#    'auto_merge': None,
#    'active_lock_reason': None,
#    'merged': False,
#    'mergeable': True,
#    'rebaseable': True,
#    'mergeable_state': 'clean',
#    'merged_by': None,
#    'comments': 0,
#    'review_comments': 0,
#    'maintainer_can_modify': False,
#    'commits': 17,
#    'additions': 48,
#    'deletions': 27,
#    'changed_files': 14}},
#  'public': True,
#  'created_at': '2025-02-19T07:29:21Z'}

# %% [markdown]
# #### API(application programming interface)
#
# 데이터를 주고 받는 규격

# %%
lotto_url = 'https://www.dhlottery.co.kr/common.do'

payload = {
    'method': 'getLottoNumber',
    'drwNo': 1158
}

# %%
r = requests.get(lotto_url, params = payload)
# print(r.url) ### 주소 불러오기
print(r.text) ### 호출한주소가 갖고 있는 내용 출력, dtype = json
lotto_dict = r.json() ### dtype = dict
# Out:
# {"totSellamnt":119706159000,"returnValue":"success","drwNoDate":"2025-02-08","firstWinamnt":1394358197,"drwtNo6":38,"drwtNo4":32,"firstPrzwnerCo":21,"drwtNo5":37,"bnusNo":20,"firstAccumamnt":29281522137,"drwNo":1158,"drwtNo2":25,"drwtNo3":27,"drwtNo1":21}

# %%
print(lotto_dict['drwNoDate'])
print(lotto_dict['drwtNo1'])
print(lotto_dict['drwtNo2'])
print(lotto_dict['drwtNo3'])
print(lotto_dict['drwtNo4'])
print(lotto_dict['drwtNo5'])
print(lotto_dict['drwtNo6'])
# Out:
# 2025-02-08
# 21
# 25
# 27
# 32
# 37
# 38

# %%
for i in range(1,7):
    print(lotto_dict[f'drwtNo{i}'])
# Out:
# 21
# 25
# 27
# 32
# 37
# 38

# %% [markdown]
# #### 실습
# 페어프로그래밍
# 로또 결과를 출력해서 그 결과가 1등 당첨인지 확인하기
# - 로또 5000원 구매 하기
#     - 랜덤으로 5개의 로또 번호를 생성합니다
# - 등수 확인하기
#     - 최신회차의 당첨번호와 생성된 번호를 비교하여 몇등인지 출력합니다.
#     - 1,3,4,5, 꽝
#     - 2등

# %%
lotto_url = 'https://www.dhlottery.co.kr/common.do'

payload = {
    'method': 'getLottoNumber',
    'drwNo': 1159
}


r = requests.get(lotto_url, params = payload)
# print(r.url) ### 주소 불러오기
print(r.text) ### 호출한주소가 갖고 있는 내용 출력, dtype = json
lotto_dict = r.json() ### dtype = dict
# Out:
# {"totSellamnt":124802304000,"returnValue":"success","drwNoDate":"2025-02-15","firstWinamnt":1284854250,"drwtNo6":39,"drwtNo4":28,"firstPrzwnerCo":23,"drwtNo5":38,"bnusNo":7,"firstAccumamnt":29551647750,"drwNo":1159,"drwtNo2":9,"drwtNo3":27,"drwtNo1":3}

# %%
game_five = [[1,2,3,4,5,6],[1,2,3,4,5,7],[1,2,3,4,8,9],[1,2,3,10,11,12],[1,2,22,24,25,26]] # 1등 , 2등, 4등, 5등, 꽝
my_list = [1,2,3,4,5,6,7]

for i in game_five[:]:
    print(i)
    game_five.remove(i)
    print(game_five)



game_five_copy = game_five[:]
for i in game_five_copy:
    correct_count = 0
    for k in my_list[:6]:
        if k in i:
            correct_count += 1
    print(correct_count)
    if correct_count == 6:
        print('1등입니다.')
        game_five.remove(i)
        continue
    correct_count = 0
    for j in my_list:
        if j in i:
            correct_count += 1
    if correct_count == 6:
        print('2등입니다.')
    elif correct_count == 5:
        print('3등입니다.')
    elif correct_count == 4:
        print('4등입니다.')
    elif correct_count == 3:
        print('5등입니다.')
    else:
        print('꽝입니다.')
# Out:
# 6
# 1등입니다.
# 5
# 2등입니다.
# 4
# 4등입니다.
# 3
# 5등입니다.
# 2
# 꽝입니다.

# %%
## 1. 5게임 만들기
import random

my_game_number = []

for i in range(5):
    my_number = random.sample(range(1,46),6)
    my_game_number.append(my_number)

print(my_game_number)


## 2. 로또 당첨번호 가져오기
lotto_dict

Lotto_number = []
for i in range(1,7):
    Lotto_number.append(lotto_dict[f'drwtNo{i}'])

Lotto_number
bonus_number = lotto_dict['bnusNo']

## 3. 등수 확인하기
for i in my_game_number:
    my_game_set = set(i)
    Lotto_number_set = set(Lotto_number)

    set_count = len(my_game_set & Lotto_number_set)

    if set_count == 6:
        print('1등입니다')
    elif set_count == 5 and bonus_number in my_game_set:
        print('2등입니다')
    elif set_count == 5:
        print('3등입니다')
    elif set_count == 4:
        print('4등입니다')
    elif set_count == 3:
        print('5등입니다')
    else:
        print('꽝입니다')
# Out:
# [[22, 4, 15, 32, 30, 39], [31, 33, 41, 32, 29, 39], [39, 20, 11, 5, 44, 30], [7, 11, 9, 40, 5, 16], [6, 43, 13, 22, 45, 29]]
# 꽝입니다
# 꽝입니다
# 꽝입니다
# 꽝입니다
# 꽝입니다

# %% [markdown]
# 1. 로또는 ***비복원 추출***로 번호를 추첨 하기 때문에 sample을 활용하여 번호를 랜덤으로 추출한다.
#     <span style="font-size: 13px; color: green">\* 다만 로또의 번호는 1부터 45까지 랜덤으로 6개의 숫자를 뽑으며, 보너스 번호가 존재</span>
# 2. 각 기준에 맞추어 1등 당첨 번호와 내가 구매한 게임의 번호가 몇개가 겹치는지 확인이 필요.
#     1등: 6개 전부 일치
#     2등: 5개 일치 + 보너스번호 일치
#     3등: 5개 번호 일치
#     4등: 4개 번호 일치
#     5등: 3개 번호 일치
#     꽝 : 2개 이하 일치
# 3. set()을 활용하여 내 게임 번호와 당첨번호를 dict()형태로 바꾸어 교집합 데이터 확인.
#     <span style="font-size: 13px; color: green">\* 다만 list와 list에는 &를 사용할 수 없다.</span>
# 4. len()을 활용하여 교집합된 데이터의 갯수 확인.
# 5. 교집합 데이터 갯수와 조건문(if-elif-else)를 활용하여 갯수에 따른 결과 출력.
#      <span style="font-size: 13px; color: green">\* 다만 2등은 6개의 당첨 번호 중 5개를 맞추고 ***그리고*** 보너스 번호를 맞춰서 총 6개를 맞춰야 함 -> and를 활용하여 and앞과 뒤에 있는 조건 둘다를 만족 했을 경우 2등이 출력이 되도록 한다.</span>
